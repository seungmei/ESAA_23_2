# %% [markdown]
# <a href="https://colab.research.google.com/github/seungmei/ESAA_23_2/blob/main/%EB%AF%B8%EB%8B%88%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %%
train=pd.read_csv("/content/movies_train.csv")
test=pd.read_csv("/content/movies_test.csv")
submission=pd.read_csv("/content/submission.csv")

# %%
#1번 스텝수에 따른 관객수
train_staff=train.loc[:,['num_staff','box_off_num']]
train_staff
# Out:
#      num_staff  box_off_num
# 0           91        23398
# 1          387      7072501
# 2          343      6959083
# 3           20       217866
# 4          251       483387
# ..         ...          ...
# 595        510      1475091
# 596        286      1716438
# 597        123         2475
# 598        431      2192525
# 599        363      7166532
#
# [600 rows x 2 columns]

# %%
train_staff.groupby('num_staff').agg(['count', 'mean'])
# Out:
#           box_off_num
#                 count          mean
# num_staff
# 0                  32  7.805562e+03
# 1                  15  3.715520e+04
# 2                  15  3.692873e+04
# 3                  12  4.034653e+05
# 4                   7  4.129286e+03
# ...               ...           ...
# 683                 1  2.260512e+06
# 687                 1  7.482180e+06
# 719                 1  2.192276e+06
# 868                 1  8.666208e+06
# 869                 1  1.426277e+07
#
# [296 rows x 2 columns]

# %%
train_staff_box=pd.DataFrame(train_staff.groupby(['num_staff'],as_index=False).mean())
train_staff_box
# Out:
#      num_staff   box_off_num
# 0            0  7.805562e+03
# 1            1  3.715520e+04
# 2            2  3.692873e+04
# 3            3  4.034653e+05
# 4            4  4.129286e+03
# ..         ...           ...
# 291        683  2.260512e+06
# 292        687  7.482180e+06
# 293        719  2.192276e+06
# 294        868  8.666208e+06
# 295        869  1.426277e+07
#
# [296 rows x 2 columns]

# %%
plt.bar(train_staff_box['num_staff'],train_staff_box['box_off_num'])
plt.xlabel('num_staff', fontsize=14)
plt.ylabel('box_off_num', fontsize=14)
plt.show()

# %%
train_staff_box.corr()
#중상정도의 상관관계를 가진다고 볼 수 있다.
# Out:
#              num_staff  box_off_num
# num_staff     1.000000     0.546622
# box_off_num   0.546622     1.000000

# %%
#4번 연도별 관객수 top3

train['release_time']=pd.to_datetime(train['release_time'])

# %%
train['release_year']=train['release_time'].dt.year

# %%
train[['release_year','box_off_num']].groupby('release_year').mean().sort_values('box_off_num', ascending=False)
# Out:
#                box_off_num
# release_year
# 2013          1.007358e+06
# 2012          9.457252e+05
# 2011          6.288671e+05
# 2015          5.958692e+05
# 2014          5.938845e+05
# 2010          5.416582e+05

# %%
train_year_top3 = train.sort_values(by="box_off_num", ascending=False).groupby("release_year").head(3)
train_year_top3
# Out:
#                  title      distributor genre release_time  time  \
# 372               국제시장        CJ 엔터테인먼트   드라마   2014-12-17   126
# 362                도둑들           (주)쇼박스   느와르   2012-07-25   135
# 530            7번방의 선물           (주)NEW   코미디   2013-01-23   127
# 498                 암살           (주)쇼박스    액션   2015-07-22   139
# 460        광해, 왕이 된 남자        CJ 엔터테인먼트   드라마   2012-09-13   131
# 122                변호인           (주)NEW   드라마   2013-12-18   127
# 496               설국열차        CJ 엔터테인먼트    SF   2013-08-01   125
# 505       해적: 바다로 간 산적         롯데엔터테인먼트    SF   2014-08-06   130
# 476             수상한 그녀        CJ 엔터테인먼트   코미디   2014-01-22   124
# 322               히말라야        CJ 엔터테인먼트   드라마   2015-12-16   124
# 320             최종병기 활         롯데엔터테인먼트    액션   2011-08-10   122
# 16                  써니  CJ E&M Pictures   코미디   2011-05-04   124
# 1                 내부자들           (주)쇼박스   느와르   2015-11-19   130
# ...

# %%
#10번 상영등급에 따른 영화 시간
[['screening_rat','time']].groupby('screening_rat').mean()
# Out:
#                      time
# screening_rat
# 12세 관람가        101.549020
# 15세 관람가        106.935644
# 전체 관람가          89.847826
# 청소년 관람불가        99.475490

# %%
train[['screening_rat','time']].groupby('screening_rat').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='screening_rat'>

# %%
boxplot=plt.subplots()
boxplot=sns.boxplot(x='screening_rat', y='time', data=train)

# %%
#전체관람가의 경우에 상영시간이 짧다. 어린이가 보는 걸 고려해 영화 시간을 짧게 했다고 예상할 수 있다.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %%
# 데이터 불러오기
train=pd.read_csv("/movies_train.csv")
train

# %%
train.columns

# %%
# 2번
train_actor=train.loc[:,['num_actor','box_off_num']]
train_actor

# %%
train_actor.groupby('num_actor').agg(['count','mean'])

# %%
train_actor_box=pd.DataFrame(train_actor.groupby(['num_actor'],as_index=False).mean())
train_actor_box

# %%
plt.bar(train_actor_box['num_actor'],train_actor_box['box_off_num'])
plt.xlabel('num_actor', fontsize=14)
plt.ylabel('box_off_num', fontsize=14)
plt.show()

# %%
train_actor_box.corr()

# %%
# 5번
train_staff=train.loc[:,['num_staff','distributor']]
train_staff

# %%
train_staff_mix=train_staff.groupby(['distributor'],as_index=False).agg(['count','mean'])
train_staff_mix

# %%
train_staff_mix.corr()

# %%
train_staff_std=pd.DataFrame(train_staff.groupby(['distributor'],as_index=False).agg(['count','std']))
train_staff_std = train_staff_std[train_staff_std.num_staff['count'] != 1]
train_staff_std

# %%
train_staff_std.num_staff['std'].mean()

# %%
plt.bar(train_staff_mix[('num_staff','count')],train_staff_mix[('num_staff','mean')])
plt.xlabel('count', fontsize=14)
plt.ylabel('mean of num_staff', fontsize=14)
plt.show()

# %%
# 8번
train_time=train.loc[:,['time','box_off_num']]
train_time

# %%
train_time_mean=pd.DataFrame(train_time.groupby(['time'],as_index=False).mean())
train_time_mean

# %%
plt.bar(train_time_mean['time'],train_time_mean['box_off_num'])
plt.xlabel('time', fontsize=14)
plt.ylabel('mean of box_off_num', fontsize=14)
plt.show()

# %%
# 11번
train_num=train.loc[:,['num_actor','num_staff']]
train_num

# %%
train_num_mean=pd.DataFrame(train_num.groupby(['num_actor'],as_index=False).mean())
train_num_mean

# %%
plt.bar(train_num_mean['num_actor'],train_num_mean['num_staff'])
plt.xlabel('num_actor', fontsize=14)
plt.ylabel('mean of num_staff', fontsize=14)
plt.show()

# %%
train_num_mean.corr()

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic') #matplotlib 한글 깨짐 방지

import warnings
warnings.filterwarnings(action='ignore')

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# 데이터 불러오기
train=pd.read_csv("/content/gdrive/MyDrive/ESAA/Data/movies_train.csv")

# %%
train.isna().sum()

# %%
# 결측값의 특성 확인
train[train['dir_prev_bfnum'].isna()].head(3)

# %%
print(train[train['dir_prev_bfnum'].isna()]['dir_prev_num'].sum())
# Out:
# 0

# %%
train['release_time']=pd.to_datetime(train['release_time'])

# %%
##전작 영화가 있으면 새로 만든 칼럼, prev_movies에 'Yes'를, 없으면 'No'를 대입함.

#train 세트에 prev_movies 칼럼을 추가하고 데이터값을 Yes로 대입
train['prev_movies']='Yes'

#dir_prev_num의 데이터값이 0일 경우는 칼럼 prev_movies의 데이터값에 No를 대입
for i in range(600):
    if train.loc[i,'dir_prev_num']==0:
        train.loc[i,'prev_movies']='No'

# %%
#prev_movies를 groupby로 분류함.(Yes,No)
train[['prev_movies','box_off_num']].groupby('prev_movies')

# %%
#groupby로 분류한 prev_movies에 따른 평균 관객수(box_off_num)
train[['prev_movies','box_off_num']].groupby('prev_movies').mean().sort_values('box_off_num')
# Out:
#              box_off_num
# prev_movies
# No              349204.3
# Yes            1146932.0

# %%
ax = plt.subplots()
ax = sns.barplot(x='prev_movies', y='box_off_num', data=train)

# %% [markdown]
# ### 5-9) 장르별 평균 관객수

# %%
train[['genre','box_off_num']].groupby('genre').mean().sort_values('box_off_num')
# Out:
#         box_off_num
# genre
# 뮤지컬          6627.0
# 다큐멘터리       67172.3
# 서스펜스        82611.0
# 애니메이션      181926.7
# 멜로/로맨스     425968.0
# 미스터리       527548.2
# 공포         590832.5
# 드라마        625689.8
# 코미디       1193914.0
# SF        1788345.7
# 액션        2203974.1
# 느와르       2263695.1

# %%
ax = plt.subplots()
ax = sns.barplot(x='genre', y='box_off_num', data=train)

# %% [markdown]
# - 느와르가 가장 관객수가 많은 편이고 그 다음으로는 액션, SF, 코메디 순이다. 평균 관객수가 가장 낮은 영화 장르는 뮤지컬, 다큐멘터리 순이다.

# %% [markdown]
# ### 5-12) 감독의 전작 관객 수와 관객수

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(train['dir_prev_bfnum'], train['box_off_num'])

# %%
#dir_prev_bfnum과 box_off_num 의 상관관계
train['dir_prev_bfnum'].corr(train['box_off_num'], method='pearson')
# Out:
# 0.2937908144182463

# %% [markdown]
# 감독의 전작 영화 관객수와 영화 관객수 사이의 산점도와 상관계수를 보아 유의미한 관계가 아님을 알 수 있다.
